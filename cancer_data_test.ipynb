# %% [markdown]
# <a href="https://colab.research.google.com/github/abhipavuluri/ds-numpy/blob/main/cancer_data_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from seaborn import

# %%
df = pd.read_csv("https://gist.githubusercontent.com/KhanradCoder/35a6beea49e5b9ba62797e595a9626c0/raw/8974e055bdf3a9d7e6cacf1c1c30fcfd2ffd6de3/cancer.csv")
df.describe()
# Out:
#        diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# count           569.000000   569.000000    569.000000      569.000000
# mean              0.372583    14.127292     19.289649       91.969033
# std               0.483918     3.524049      4.301036       24.298981
# min               0.000000     6.981000      9.710000       43.790000
# 25%               0.000000    11.700000     16.170000       75.170000
# 50%               0.000000    13.370000     18.840000       86.240000
# 75%               1.000000    15.780000     21.800000      104.100000
# max               1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# ...

# %%
df[:5]
# Out:
#    diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0                    1        17.99         10.38          122.80     1001.0
# 1                    1        20.57         17.77          132.90     1326.0
# 2                    1        19.69         21.25          130.00     1203.0
# 3                    1        11.42         20.38           77.58      386.1
# 4                    1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...
